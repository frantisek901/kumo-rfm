# %% [markdown]
# # KumoRFM Predictive Query Tutorial

# %% [markdown]
# ## Setup Dataset
#
# ## About the Dataset
# This tutorial uses Steam gaming data with three tables:
# - `users`: Gaming platform users
# - `games`: Video games with pricing/metadata
# - `reviews`: User reviews and ratings
#
# We'll predict things like: game discounts, user behavior, and review patterns.

# %%
# !pip install kumoai fsspec s3fs
# Out:
# Requirement already satisfied: kumoai in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (2.12.0.dev202511061731)
# Requirement already satisfied: fsspec in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (2025.10.0)
# Requirement already satisfied: s3fs in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (2025.10.0)
# Requirement already satisfied: pandas in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from kumoai) (2.3.3)
# Requirement already satisfied: pyarrow<19.0.0,>=8.0.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from kumoai) (18.1.0)
# Requirement already satisfied: requests>=2.28.2 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from kumoai) (2.32.3)
# Requirement already satisfied: urllib3 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from kumoai) (2.5.0)
# Requirement already satisfied: plotly in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from kumoai) (6.4.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\program files\positron\resources\app\extensions\positron-python\python_files\lib\ipykernel\py3 (from kumoai) (4.15.0)
# Requirement already satisfied: kumo-api==0.45.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from kumoai) (0.45.0)
# Requirement already satisfied: tqdm>=4.66.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from kumoai) (4.67.0)
# Requirement already satisfied: aiohttp>=3.10.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from kumoai) (3.12.14)
# Requirement already satisfied: pydantic>=1.10.21 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from kumoai) (2.12.4)
# Requirement already satisfied: rich>=9.0.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from kumoai) (14.0.0)
# Requirement already satisfied: protobuf>=3.19.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from kumo-api==0.45.0->kumoai) (6.31.1)
# Requirement already satisfied: aiobotocore<3.0.0,>=2.5.4 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from s3fs) (2.25.1)
# Requirement already satisfied: aioitertools<1.0.0,>=0.5.1 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs) (0.13.0)
# Requirement already satisfied: botocore<1.40.62,>=1.40.46 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs) (1.40.61)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\program files\positron\resources\app\extensions\positron-python\python_files\lib\ipykernel\py3 (from aiobotocore<3.0.0,>=2.5.4->s3fs) (2.9.0.post0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs) (1.0.1)
# Requirement already satisfied: multidict<7.0.0,>=6.0.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs) (6.6.3)
# Requirement already satisfied: wrapt<2.0.0,>=1.10.10 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs) (1.16.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from aiohttp>=3.10.0->kumoai) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from aiohttp>=3.10.0->kumoai) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from aiohttp>=3.10.0->kumoai) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from aiohttp>=3.10.0->kumoai) (1.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from aiohttp>=3.10.0->kumoai) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from aiohttp>=3.10.0->kumoai) (1.20.1)
# Requirement already satisfied: six>=1.5 in c:\program files\positron\resources\app\extensions\positron-python\python_files\lib\ipykernel\py3 (from python-dateutil<3.0.0,>=2.1->aiobotocore<3.0.0,>=2.5.4->s3fs) (1.17.0)
# Requirement already satisfied: idna>=2.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from yarl<2.0,>=1.17.0->aiohttp>=3.10.0->kumoai) (3.10)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from pydantic>=1.10.21->kumoai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from pydantic>=1.10.21->kumoai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from pydantic>=1.10.21->kumoai) (0.4.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.28.2->kumoai) (3.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.28.2->kumoai) (2024.8.30)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from rich>=9.0.0->kumoai) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\program files\positron\resources\app\extensions\positron-python\python_files\lib\ipykernel\py3 (from rich>=9.0.0->kumoai) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from markdown-it-py>=2.2.0->rich>=9.0.0->kumoai) (0.1.2)
# Requirement already satisfied: colorama in c:\users\user\appdata\roaming\python\python313\site-packages (from tqdm>=4.66.0->kumoai) (0.4.6)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from pandas->kumoai) (2.3.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from pandas->kumoai) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from pandas->kumoai) (2024.2)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from plotly->kumoai) (2.10.2)
# Requirement already satisfied: packaging in c:\program files\positron\resources\app\extensions\positron-python\python_files\lib\ipykernel\py3 (from plotly->kumoai) (25.0)
# WARNING: Ignoring invalid distribution ~angchain-community (C:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~angchain-community (C:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~angchain-community (C:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages)

# %%
import os
import kumoai.experimental.rfm as rfm

# %%
if not os.environ.get("KUMO_API_KEY"):
    rfm.authenticate()
# Out:
# Opening browser page to automatically generate an API key...
# If the page does not open, manually create a new API key at https://kumorfm.ai/api-keys and set it using os.environ["KUMO_API_KEY"] = "YOUR_API_KEY"
# [2025-11-07 21:50:03 - kumoai:301 - INFO] Generated token "sdk-desktop-fa1d88v-2025-11-07-21-49-57-Z" and saved to KUMO_API_KEY env variable

# %%
# Initialize a Kumo client with your API key:
KUMO_API_KEY = os.environ.get("KUMO_API_KEY")
rfm.init(api_key=KUMO_API_KEY)
# Out:
# [2025-11-07 21:50:20 - kumoai:204 - INFO] Successfully initialized the Kumo SDK (version 2.12.0.dev202511061731) against deployment https://kumorfm.ai/api, with log level INFO.

# %%
import pandas as pd

# Take about 20s to download
df_dict = {
    'users': pd.read_csv(f's3://kumo-sdk-public/rfm-datasets/steam_game_sample/users.csv'),
    'games': pd.read_csv(f's3://kumo-sdk-public/rfm-datasets/steam_game_sample/games.csv'),
    'reviews': pd.read_csv(f's3://kumo-sdk-public/rfm-datasets/steam_game_sample/recommendations.csv')
}
df_dict['reviews']['is_recommended'] = df_dict['reviews']['is_recommended'].astype(int)

# %%
# Take a look at the data
df_dict['users'].head(3)
# Out:
#    user_id  products  reviews
# 0  7922733       108        2
# 1  5029439       397        2
# 2  6696498       290        1

# %%
df_dict['games'].head(3)
# Out:
#    app_id                              title date_release   win    mac  linux  \
# 0   13500  Prince of Persia: Warrior Within™   2008-11-21  True  False  False
# 1  113020       Monaco: What's Yours Is Mine   2013-04-24  True   True   True
# 2  226560                 Escape Dead Island   2014-11-18  True  False  False
#
#           rating  positive_ratio  user_reviews  price_final  price_original  \
# 0  Very Positive              84          2199         9.99            9.99
# 1  Very Positive              92          3722        14.99           14.99
# 2          Mixed              61           873        14.99           14.99
#
#    discount  steam_deck                                        description  \
# 0       0.0        True  Enter the dark underworld of Prince of Persia ...
# 1       0.0        True  Monaco: What's Yours Is Mine is a single playe...
# 2       0.0        True  Escape Dead Island is a Survival-Mystery adven...
#
#                                                 tags
# 0  ['Action', 'Adventure', 'Parkour', 'Third Pers...
# 1  ['Co-op', 'Stealth', 'Indie', 'Heist', 'Local ...
# 2  ['Zombies', 'Adventure', 'Survival', 'Action',...

# %%
df_dict['reviews'].head(3)
# Out:
#    app_id  helpful  funny        date  is_recommended  hours  user_id  \
# 0   42700        6      2  2019-10-19               0    5.9   433335
# 1  376210        0      0  2021-03-01               1  114.2   944679
# 2   39210        0      0  2021-04-09               1  123.1  5261084
#
#    review_id
# 0         27
# 1         75
# 2        141

# %%
import kumoai.experimental.rfm as rfm

users_table = rfm.LocalTable(df = df_dict['users'], name = "users").infer_metadata()
games_table = rfm.LocalTable(df = df_dict['games'], name = "games").infer_metadata()
reviews_table = rfm.LocalTable(df = df_dict['reviews'], name = "reviews").infer_metadata()
# Out:
# Detected primary key 'user_id' in table 'users'
# Detected time column 'date_release' in table 'games'
# Detected primary key 'review_id' and time column 'date' in table 'reviews'

# %%
games_table.primary_key = "app_id"
games_table['discount'].stype = "numerical"
reviews_table['is_recommended'].stype = "numerical"
reviews_table['helpful'].stype = "numerical"

# %%
from kumoai.experimental.rfm import LocalGraph
graph = LocalGraph(tables=[users_table, games_table, reviews_table])
graph.infer_links()
graph.unlink("users", "reviews", "reviews")
graph.unlink("games", "user_reviews", "reviews")

graph.validate()
# Out:
# 🕸️ Graph Links (FK ↔️ PK):
# • reviews.app_id ↔️ games.app_id
# • games.user_reviews ↔️ reviews.review_id
# • users.reviews ↔️ reviews.review_id
# • reviews.user_id ↔️ users.user_id
# LocalGraph(
#   tables=[
#     users,
#     games,
#     reviews,
#   ],
#   edges=[
#     reviews.user_id ⇔ users.user_id,
#     reviews.app_id ⇔ games.app_id,
#   ],
# )

# %%
graph.visualize()
# Out:
# ---------------------------------------------------------------------------
#
# RuntimeError                              Traceback (most recent call last)
#
# Cell In[18], line 1
#
# ----> 1 graph.visualize()
#
#
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\kumoai\experimental\rfm\local_graph.py:653, in LocalGraph.visualize(self, path, show_columns)
#
#     650     raise ModuleNotFoundError("The 'graphviz' package is required for "
#
#     651                               "visualization")
#
#     652 elif not has_graphviz_executables():
#
# --> 653     raise RuntimeError("Could not visualize graph as 'graphviz' "
#
#     654                        "executables are not installed. These "
#
#     655                        "dependencies are required in addition to the "
#
#     656                        "'graphviz' Python package. Please install "
#
#     657                        "them as described at "
#
#     658                        "https://graphviz.org/download/.")
#
#     659 else:
#
#     660     import graphviz
#
#
#
# RuntimeError: Could not visualize graph as 'graphviz' executables are not installed. These dependencies are required in addition to the 'graphviz' Python package. Please install them as described at https://graphviz.org/download/.

# %%
from kumoai.experimental.rfm import KumoRFM

model = KumoRFM(graph)
# Out:
# ⠏  Materializing graph (1.79s)
#    ↳ Sanitized input data
#    ↳ Collected primary keys from 3 tables
# ⠙  Materializing graph (1.90s)
#    ↳ Sanitized input data
#    ↳ Collected primary keys from 3 tables
# ⠹  Materializing graph (2.02s)
#    ↳ Sanitized input data
#    ↳ Collected primary keys from 3 tables
# ⠸  Materializing graph (2.12s)
#    ↳ Sanitized input data
#    ↳ Collected primary keys from 3 tables
# ⠴  Materializing graph (2.24s)
#    ↳ Sanitized input data
#    ↳ Collected primary keys from 3 tables
# ⠦  Materializing graph (2.34s)
#    ↳ Sanitized input data
#    ↳ Collected primary keys from 3 tables
# ⠧  Materializing graph (2.45s)
#    ↳ Sanitized input data
#    ↳ Collected primary keys from 3 tables
# ⠏  Materializing graph (2.55s)
#    ↳ Sanitized input data
#    ↳ Collected primary keys from 3 tables
# ✅ Materializing graph (2.64s)
#    ↳ Sanitized input data
#    ↳ Collected primary keys from 3 tables
#    ↳ Identified temporal graph from 1997-06-30 to 2023-08-24
# ✅ Materializing graph (2.64s)
#    ↳ Sanitized input data
#    ↳ Collected primary keys from 3 tables
#    ↳ Identified temporal graph from 1997-06-30 to 2023-08-24
#    ↳ Created graph with 2,774,529 nodes and 8,226,992 edges

# %% [markdown]
# ## Predictive Query Language
#
# **Predictive Query Language (PQL)** is a declarative, SQL-like syntax that lets you frame an entire ML task in a single statement.
#
# ---
#
# ### Anatomy of a Predictive Query
#
# ```
# PREDICT <target_expression>
# FOR <entity_specification>
# [WHERE <filters>]
# ```
#
# | Component              | Purpose                                                                                                               |
# | ---------------------- | --------------------------------------------------------------------------------------------------------------------- |
# | **PREDICT**            | Declares the *target*—the value you want the model to output. Can be a column or an aggregation over a future window. |
# | **FOR**                | Tells the model *who* (entity) to predict for. In RFM you provide an explicit ID or `IN (...)` list.                  |
# | **WHERE** *(optional)* | Filters the *context* used to build features; does **not** limit the entity list you pass in `FOR`.                   |
#
# ---
#
# ### Writing Queries in Kumo
#
# These are the five steps to prepare writing predictive queries in Kumo.
# 1. **Choose your entity** - the table and primary-key column you'll predict for.
# 2. **Define the target** - a raw column *or* an aggregation across a future horizon.
# 3. **Pin the entity list** - pass a single ID or `IN (...)` list after `FOR`.
# 4. *(Optional)* **Refine the context** - use `WHERE` with static or temporal filters to restrict feature generation.
# 5. **Run & fetch** - execute `rfm.query(<your_pql>)` and read the JSON result.

# %% [markdown]
# ## Use Cases

# %% [markdown]
# ### Scalar Prediction
# Let's start with a simple scalar prediction: predicting the discount amount for a specific game (app_id 113020).
#
# **Important**: The entity column (`games.app_id`) must be the primary key - this tells the model which specific game to predict for.

# %%
query = """PREDICT games.discount

FOR games.app_id = 113020
"""

prediction_result = model.predict(query)
print(prediction_result)
# Out:
# ⠋  PREDICT games.discount FOR games.app_id = 113020 (0.16s)
#    ↳ Identified static regression task
#    ↳ Derived anchor time 2023-08-24
# ⠙  PREDICT games.discount FOR games.app_id = 113020 (0.28s)
#    ↳ Identified static regression task
#    ↳ Derived anchor time 2023-08-24
# ⠸  PREDICT games.discount FOR games.app_id = 113020 (0.40s)
#    ↳ Identified static regression task
#    ↳ Derived anchor time 2023-08-24
# ⠼  PREDICT games.discount FOR games.app_id = 113020 (0.51s)
#    ↳ Identified static regression task
#    ↳ Derived anchor time 2023-08-24
# ⠦  PREDICT games.discount FOR games.app_id = 113020 (0.64s)
#    ↳ Identified static regression task
#    ↳ Derived anchor time 2023-08-24
# ⠧  PREDICT games.discount FOR games.app_id = 113020 (0.75s)
#    ↳ Identified static regression task
#    ↳ Derived anchor time 2023-08-24
# ⠏  PREDICT games.discount FOR games.app_id = 113020 (0.86s)
#    ↳ Identified static regression task
#    ↳ Derived anchor time 2023-08-24
# ⠋  PREDICT games.discount FOR games.app_id = 113020 (0.98s)
#    ↳ Identified static regression task
#    ↳ Derived anchor time 2023-08-24
#    ↳ Collected 1,000 in-context examples with targets between 0 and 90
# ⠹  PREDICT games.discount FOR games.app_id = 113020 (1.10s)
#    ↳ Identified static regression task
#    ↳ Derived anchor time 2023-08-24
#    ↳ Collected 1,000 in-context examples with targets between 0 and 90
# ⠸  PREDICT games.discount FOR games.app_id = 113020 (1.21s)
#    ↳ Identified static regression task
#    ↳ Derived anchor time 2023-08-24
#    ↳ Collected 1,000 in-context examples with targets between 0 and 90
# ⠼  PREDICT games.discount FOR games.app_id = 113020 (1.32s)
#    ↳ Identified static regression task
#    ↳ Derived anchor time 2023-08-24
#    ↳ Collected 1,000 in-context examples with targets between 0 and 90
# ⠦  PREDICT games.discount FOR games.app_id = 113020 (1.44s)
#    ↳ Identified static regression task
#    ↳ Derived anchor time 2023-08-24
#    ↳ Collected 1,000 in-context examples with targets between 0 and 90
# ⠧  PREDICT games.discount FOR games.app_id = 113020 (1.55s)
#    ↳ Identified static regression task
#    ↳ Derived anchor time 2023-08-24
#    ↳ Collected 1,000 in-context examples with targets between 0 and 90
# ⠏  PREDICT games.discount FOR games.app_id = 113020 (1.66s)
#    ↳ Identified static regression task
#    ↳ Derived anchor time 2023-08-24
#    ↳ Collected 1,000 in-context examples with targets between 0 and 90
# ⠋  PREDICT games.discount FOR games.app_id = 113020 (1.77s)
#    ↳ Identified static regression task
#    ↳ Derived anchor time 2023-08-24
#    ↳ Collected 1,000 in-context examples with targets between 0 and 90
# ⠙  PREDICT games.discount FOR games.app_id = 113020 (1.88s)
#    ↳ Identified static regression task
#    ↳ Derived anchor time 2023-08-24
#    ↳ Collected 1,000 in-context examples with targets between 0 and 90
# ⠸  PREDICT games.discount FOR games.app_id = 113020 (1.99s)
#    ↳ Identified static regression task
#    ↳ Derived anchor time 2023-08-24
#    ↳ Collected 1,000 in-context examples with targets between 0 and 90
# ⠼  PREDICT games.discount FOR games.app_id = 113020 (2.09s)
#    ↳ Identified static regression task
#    ↳ Derived anchor time 2023-08-24
#    ↳ Collected 1,000 in-context examples with targets between 0 and 90
# ⠴  PREDICT games.discount FOR games.app_id = 113020 (2.20s)
#    ↳ Identified static regression task
#    ↳ Derived anchor time 2023-08-24
#    ↳ Collected 1,000 in-context examples with targets between 0 and 90
# ⠧  PREDICT games.discount FOR games.app_id = 113020 (2.32s)
#    ↳ Identified static regression task
#    ↳ Derived anchor time 2023-08-24
#    ↳ Collected 1,000 in-context examples with targets between 0 and 90
# ⠇  PREDICT games.discount FOR games.app_id = 113020 (2.42s)
#    ↳ Identified static regression task
#    ↳ Derived anchor time 2023-08-24
#    ↳ Collected 1,000 in-context examples with targets between 0 and 90
# ⠏  PREDICT games.discount FOR games.app_id = 113020 (2.53s)
#    ↳ Identified static regression task
#    ↳ Derived anchor time 2023-08-24
#    ↳ Collected 1,000 in-context examples with targets between 0 and 90
# ⠙  PREDICT games.discount FOR games.app_id = 113020 (2.65s)
#    ↳ Identified static regression task
#    ↳ Derived anchor time 2023-08-24
#    ↳ Collected 1,000 in-context examples with targets between 0 and 90
# ⠹  PREDICT games.discount FOR games.app_id = 113020 (2.76s)
#    ↳ Identified static regression task
#    ↳ Derived anchor time 2023-08-24
#    ↳ Collected 1,000 in-context examples with targets between 0 and 90
# ⠼  PREDICT games.discount FOR games.app_id = 113020 (2.87s)
#    ↳ Identified static regression task
#    ↳ Derived anchor time 2023-08-24
#    ↳ Collected 1,000 in-context examples with targets between 0 and 90
# ⠴  PREDICT games.discount FOR games.app_id = 113020 (2.99s)
#    ↳ Identified static regression task
#    ↳ Derived anchor time 2023-08-24
#    ↳ Collected 1,000 in-context examples with targets between 0 and 90
# ⠧  PREDICT games.discount FOR games.app_id = 113020 (3.11s)
#    ↳ Identified static regression task
#    ↳ Derived anchor time 2023-08-24
#    ↳ Collected 1,000 in-context examples with targets between 0 and 90
# ⠇  PREDICT games.discount FOR games.app_id = 113020 (3.22s)
#    ↳ Identified static regression task
#    ↳ Derived anchor time 2023-08-24
#    ↳ Collected 1,000 in-context examples with targets between 0 and 90
# ⠏  PREDICT games.discount FOR games.app_id = 113020 (3.33s)
#    ↳ Identified static regression task
#    ↳ Derived anchor time 2023-08-24
#    ↳ Collected 1,000 in-context examples with targets between 0 and 90
# ⠙  PREDICT games.discount FOR games.app_id = 113020 (3.45s)
#    ↳ Identified static regression task
#    ↳ Derived anchor time 2023-08-24
#    ↳ Collected 1,000 in-context examples with targets between 0 and 90
# ⠹  PREDICT games.discount FOR games.app_id = 113020 (3.57s)
#    ↳ Identified static regression task
#    ↳ Derived anchor time 2023-08-24
#    ↳ Collected 1,000 in-context examples with targets between 0 and 90
# ⠼  PREDICT games.discount FOR games.app_id = 113020 (3.68s)
#    ↳ Identified static regression task
#    ↳ Derived anchor time 2023-08-24
#    ↳ Collected 1,000 in-context examples with targets between 0 and 90
# ⠴  PREDICT games.discount FOR games.app_id = 113020 (3.79s)
#    ↳ Identified static regression task
#    ↳ Derived anchor time 2023-08-24
#    ↳ Collected 1,000 in-context examples with targets between 0 and 90
# ⠧  PREDICT games.discount FOR games.app_id = 113020 (3.90s)
#    ↳ Identified static regression task
#    ↳ Derived anchor time 2023-08-24
#    ↳ Collected 1,000 in-context examples with targets between 0 and 90
# ⠇  PREDICT games.discount FOR games.app_id = 113020 (4.02s)
#    ↳ Identified static regression task
#    ↳ Derived anchor time 2023-08-24
#    ↳ Collected 1,000 in-context examples with targets between 0 and 90
# ⠏  PREDICT games.discount FOR games.app_id = 113020 (4.13s)
#    ↳ Identified static regression task
#    ↳ Derived anchor time 2023-08-24
#    ↳ Collected 1,000 in-context examples with targets between 0 and 90
# ⠙  PREDICT games.discount FOR games.app_id = 113020 (4.25s)
#    ↳ Identified static regression task
#    ↳ Derived anchor time 2023-08-24
#    ↳ Collected 1,000 in-context examples with targets between 0 and 90
# ✅ PREDICT games.discount FOR games.app_id = 113020 (4.32s)
#    ↳ Identified static regression task
#    ↳ Derived anchor time 2023-08-24
#    ↳ Collected 1,000 in-context examples with targets between 0 and 90
# ✅ PREDICT games.discount FOR games.app_id = 113020 (4.32s)
#    ↳ Identified static regression task
#    ↳ Derived anchor time 2023-08-24
#    ↳ Collected 1,000 in-context examples with targets between 0 and 90
#    ↳ Generated context of size 0.31MB
#    ENTITY ANCHOR_TIMESTAMP  TARGET_PRED
# 0  113020       2023-08-24     0.065656

# %% [markdown]
# ### Boolean & Comparison Operators
#
# Raw predictions are often more useful when converted to actionable decisions. For example, "Will this game have a discount worth my attention (>$5)?"
#  We can do so with the binary and comparison operators.
#
# ```
# =   !=   <   <=   >   >=
# AND  OR   NOT
# IN   CONTAINS   STARTS WITH   ENDS WITH
# LIKE   NOT LIKE
# IS NULL   IS NOT NULL
# ```
#
# Combine them freely inside `WHERE` or as part of a boolean target such as `PREDICT ... = 0`.
#
# The specific binary operator that needs to be used depends on the datatype being compared
#
# ---

# %%
query = """PREDICT games.discount > 5

FOR games.app_id = 113020
"""

prediction_result = model.predict(query)
print(prediction_result)
# Out:
# ⠴  PREDICT games.discount > 5 FOR games.app_id = 113020 (0.12s)
#    ↳ Identified static binary classification task
#    ↳ Derived anchor time 2023-08-24
# ⠧  PREDICT games.discount > 5 FOR games.app_id = 113020 (0.24s)
#    ↳ Identified static binary classification task
#    ↳ Derived anchor time 2023-08-24
#    ↳ Collected 1,000 in-context examples with 8.30% positive cases
# ⠏  PREDICT games.discount > 5 FOR games.app_id = 113020 (0.36s)
#    ↳ Identified static binary classification task
#    ↳ Derived anchor time 2023-08-24
#    ↳ Collected 1,000 in-context examples with 8.30% positive cases
# ⠋  PREDICT games.discount > 5 FOR games.app_id = 113020 (0.48s)
#    ↳ Identified static binary classification task
#    ↳ Derived anchor time 2023-08-24
#    ↳ Collected 1,000 in-context examples with 8.30% positive cases
# ⠙  PREDICT games.discount > 5 FOR games.app_id = 113020 (0.58s)
#    ↳ Identified static binary classification task
#    ↳ Derived anchor time 2023-08-24
#    ↳ Collected 1,000 in-context examples with 8.30% positive cases
# ⠸  PREDICT games.discount > 5 FOR games.app_id = 113020 (0.70s)
#    ↳ Identified static binary classification task
#    ↳ Derived anchor time 2023-08-24
#    ↳ Collected 1,000 in-context examples with 8.30% positive cases
# ⠼  PREDICT games.discount > 5 FOR games.app_id = 113020 (0.81s)
#    ↳ Identified static binary classification task
#    ↳ Derived anchor time 2023-08-24
#    ↳ Collected 1,000 in-context examples with 8.30% positive cases
# ⠦  PREDICT games.discount > 5 FOR games.app_id = 113020 (0.93s)
#    ↳ Identified static binary classification task
#    ↳ Derived anchor time 2023-08-24
#    ↳ Collected 1,000 in-context examples with 8.30% positive cases
# ⠧  PREDICT games.discount > 5 FOR games.app_id = 113020 (1.04s)
#    ↳ Identified static binary classification task
#    ↳ Derived anchor time 2023-08-24
#    ↳ Collected 1,000 in-context examples with 8.30% positive cases
# ⠏  PREDICT games.discount > 5 FOR games.app_id = 113020 (1.16s)
#    ↳ Identified static binary classification task
#    ↳ Derived anchor time 2023-08-24
#    ↳ Collected 1,000 in-context examples with 8.30% positive cases
# ⠋  PREDICT games.discount > 5 FOR games.app_id = 113020 (1.28s)
#    ↳ Identified static binary classification task
#    ↳ Derived anchor time 2023-08-24
#    ↳ Collected 1,000 in-context examples with 8.30% positive cases
# ⠙  PREDICT games.discount > 5 FOR games.app_id = 113020 (1.38s)
#    ↳ Identified static binary classification task
#    ↳ Derived anchor time 2023-08-24
#    ↳ Collected 1,000 in-context examples with 8.30% positive cases
# ⠸  PREDICT games.discount > 5 FOR games.app_id = 113020 (1.49s)
#    ↳ Identified static binary classification task
#    ↳ Derived anchor time 2023-08-24
#    ↳ Collected 1,000 in-context examples with 8.30% positive cases
# ⠼  PREDICT games.discount > 5 FOR games.app_id = 113020 (1.60s)
#    ↳ Identified static binary classification task
#    ↳ Derived anchor time 2023-08-24
#    ↳ Collected 1,000 in-context examples with 8.30% positive cases
# ⠦  PREDICT games.discount > 5 FOR games.app_id = 113020 (1.72s)
#    ↳ Identified static binary classification task
#    ↳ Derived anchor time 2023-08-24
#    ↳ Collected 1,000 in-context examples with 8.30% positive cases
# ⠧  PREDICT games.discount > 5 FOR games.app_id = 113020 (1.82s)
#    ↳ Identified static binary classification task
#    ↳ Derived anchor time 2023-08-24
#    ↳ Collected 1,000 in-context examples with 8.30% positive cases
# ⠇  PREDICT games.discount > 5 FOR games.app_id = 113020 (1.93s)
#    ↳ Identified static binary classification task
#    ↳ Derived anchor time 2023-08-24
#    ↳ Collected 1,000 in-context examples with 8.30% positive cases
# ⠋  PREDICT games.discount > 5 FOR games.app_id = 113020 (2.04s)
#    ↳ Identified static binary classification task
#    ↳ Derived anchor time 2023-08-24
#    ↳ Collected 1,000 in-context examples with 8.30% positive cases
# ⠙  PREDICT games.discount > 5 FOR games.app_id = 113020 (2.15s)
#    ↳ Identified static binary classification task
#    ↳ Derived anchor time 2023-08-24
#    ↳ Collected 1,000 in-context examples with 8.30% positive cases
# ⠹  PREDICT games.discount > 5 FOR games.app_id = 113020 (2.26s)
#    ↳ Identified static binary classification task
#    ↳ Derived anchor time 2023-08-24
#    ↳ Collected 1,000 in-context examples with 8.30% positive cases
# ⠼  PREDICT games.discount > 5 FOR games.app_id = 113020 (2.38s)
#    ↳ Identified static binary classification task
#    ↳ Derived anchor time 2023-08-24
#    ↳ Collected 1,000 in-context examples with 8.30% positive cases
# ⠴  PREDICT games.discount > 5 FOR games.app_id = 113020 (2.49s)
#    ↳ Identified static binary classification task
#    ↳ Derived anchor time 2023-08-24
#    ↳ Collected 1,000 in-context examples with 8.30% positive cases
# ✅ PREDICT games.discount > 5 FOR games.app_id = 113020 (2.53s)
#    ↳ Identified static binary classification task
#    ↳ Derived anchor time 2023-08-24
#    ↳ Collected 1,000 in-context examples with 8.30% positive cases
# ✅ PREDICT games.discount > 5 FOR games.app_id = 113020 (2.53s)
#    ↳ Identified static binary classification task
#    ↳ Derived anchor time 2023-08-24
#    ↳ Collected 1,000 in-context examples with 8.30% positive cases
#    ↳ Generated context of size 0.31MB
#    ENTITY ANCHOR_TIMESTAMP  TARGET_PRED  False_PROB  True_PROB
# 0  113020       2023-08-24        False    0.951035   0.048965

# %% [markdown]
# ### Time-Based Aggregations
# Beyond single values, we often want to predict metrics over time windows: "How many positive reviews will this game get in the next 30 days?
#
# **Aggregation Functions In PQL**
#
# | Function         | Description               | Example                                 |
# | ---------------- | ------------------------- | --------------------------------------- |
# | `SUM`            | Sum of numeric values     | `SUM(orders.amount, 0, 30)`             |
# | `AVG`            | Average of numeric values | `AVG(sensor.temp, 0, 24, hours)`        |
# | `COUNT`          | Count of rows             | `COUNT(events.*, 0, 7)`                 |
# | `COUNT_DISTINCT` | Count of unique values    | `COUNT_DISTINCT(purchases.item, 0, 90)` |
# | `LIST_DISTINCT`  | List of unique values     | `LIST_DISTINCT(articles.tag, 0, 14)`    |
# | `MAX` / `MIN`    | Max / Min numeric value   | `MAX(speed.value, 0, 1, hours)`         |
#
# *All aggregations use a sliding window defined by* **`start`** (exclusive) *and* **`end`** (inclusive) *offsets.* Default unit is **days** but you can pass `hours` or `months` as a 4th argument.
#
# Time windows are defined relative to prediction time:
# - (0, 30): next 30 days from now
# - (-90, 0): past 90 days up to now
# - (-30, 30): 30 days before to 30 days after
#
# ---

# %%
query = """PREDICT SUM(reviews.is_recommended, 0, 180, days)

FOR users.user_id = 11227231
"""

prediction_result = model.predict(query)
print(prediction_result)

# %%
query = """PREDICT SUM(reviews.is_recommended, 0, 12, months)

FOR users.user_id = 11227231
"""

prediction_result = model.predict(query)
print(prediction_result)

# %% [markdown]
# ### Filtering Context with WHERE
#
# The WHERE clause filters which historical data is used to build features - it does not limit which entities you predict for. This improves model quality by focusing on relevant context.
# Think of this as providing only certain useful information to the model for better predictions.
#
# For example, we want our model to Only learn from data of games that had recent activity

# %%
q = """PREDICT AVG(reviews.is_recommended, 0, 12, months)
FOR games.app_id = 440
WHERE COUNT(reviews.*, -12, 0, months) > 0"""
print(model.predict(q))

# %% [markdown]
# ### WHERE inside aggregations
# Sometimes, our aggregations shouldn't be over all the values in columns but over selected values, we can then use the ```WHERE``` clause inside an aggregation then.
#
# Suppose we wanted to predict the count of helpful votes of a reviews of a game.

# %%
q = """PREDICT COUNT(reviews.* WHERE reviews.is_recommended=1,0,30, days)
FOR games.app_id=263460"""
print(model.predict(q))

# %% [markdown]
# ### Link Prediction
# So far we've predicted properties of individual entities (like a game's discount or a user's review count). Link prediction goes beyond this to predict relationships between different entities.
#
# For example, we may want to predict the TOP 3 games a user would give reviews for.

# %%
q = """PREDICT LIST_DISTINCT(reviews.app_id, 0, 12, months) RANK TOP 3
FOR users.user_id = 11764552"""
print(model.predict(q, anchor_time=pd.Timestamp('2020-09-20'), num_hops = 6))

# %% [markdown]
# ### Task Types & Automatic Detection
#
# | Pattern in `PREDICT`                | Task Type                 | Typical Metric  |
# | ----------------------------------- | ------------------------- | --------------- |
# | Raw numeric column                  | Regression                | MAE, RMSE       |
# | Boolean expression (`=`, `>`, etc.) | Binary Classification     | AUC, F1         |
# | Categorical column                  | Multiclass / Multilabel   | Accuracy, Top-k |
# | `LIST_DISTINCT(...)` + `RANK TOP k` | Link Prediction / Ranking | Recall\@k, MRR  |
#
# The SDK infers the task from your target—no extra parameters required.
#
# 4. **Watch for empty windows** - if an entity has *zero* facts in the target window, the training example is dropped.
# 5. **Start small** - iterate with a few entity IDs before scaling up queries.
#
# ### Next Steps
#
# * Explore **evaluation mode**:
#
#   ```python
#   metrics = rfm.evaluate("""YOUR PQUERY""")
#   ```
#
# Happy querying! 🚀
